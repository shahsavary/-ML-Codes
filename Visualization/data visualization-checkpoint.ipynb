# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings("ignore")
from sklearn import preprocessing
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score,f1_score,precision_score
from sklearn.model_selection import train_test_split
from scipy.stats import chi2_contingency

# %%
df=pd.read_excel(r'C:\Users\javad\OneDrive - University of Windsor\Shirin Research\research\ML Codes\Data_VIF.xlsx',index_col=0)

# %%
data2 = {'Feature': ['Alert', 'Warning', 'Stable', 'Sustainable'], 'Feature Importance': [388, 933, 316, 309]
    }
data3 = {'Feature': ['Alert', 'Warning', 'Stable', 'Sustainable'], 'Feature Importance': [933, 933, 933, 933]
    }
data4 = {'Feature': ['Alert', 'Warning', 'Stable', 'Sustainable'], 'Feature Importance': [309, 309, 309, 309]
    }

# %%
result2=pd.DataFrame(data2)
result3=pd.DataFrame(data3)
result4=pd.DataFrame(data4)

# %%
result4
# Out:
#        Feature  Feature Importance
# 0        Alert                 309
# 1      Warning                 309
# 2       Stable                 309
# 3  Sustainable                 309

# %%
plt.figure(figsize=(15,5))
# Draw first subplot using plt.subplot
plt.subplot(1, 3, 1)
plt.bar(result2['Feature'],result2['Feature Importance'], color='green')
            # Defines log scale
plt.xlabel('Acctual')
plt.ylim(0,950)


# Draw second subplot using plt.subplot
plt.subplot(1, 3, 2)
plt.bar(result4['Feature'],result4['Feature Importance'], color = 'gray')
           # Defines log scale
plt.xlabel('Under sampling')
plt.ylim(0,950)

plt.subplot(1, 3, 3)
plt.bar(result3['Feature'],result3['Feature Importance'], color = 'navy')
            # Defines log scale
plt.xlabel('Over Sampling')
plt.ylim(0,950)

# plt.savefig('subplots with log scale.pdf', dpi=300)
plt.savefig('sampling',dpi=100)

# %%
plt.figure(figsize=(24,12))
plt.subplot(3,2,1)
sns.distplot(df['GDP per capita'])
plt.subplot(3,2,2)
sns.distplot(df['GDP growth'])
plt.subplot(3,2,3)
sns.distplot(df['Population'])
plt.subplot(3,2,4)
sns.distplot(df['School enrolment '])
plt.subplot(3,2,5)
sns.distplot(df['Control of corruption'])
plt.subplot(3,2,6)
plt.hist(df['Regime types'],bottom=1)
plt.xlabel('Regime types')
plt.savefig('distplot_features',dpi=100)

# %%
dist = df['GDP per capita']
dist.hist(bins=100)

# %%
dist = df['GDP growth']
dist.hist(bins=100)

# %%
df.head()
# Out:
#              Year  GDP growth  GDP per capita  Population  School enrolment   \
# Country
# Afghanistan  2006    5.357403      263.733602  26433058.0          28.255871
# Algeria      2006    1.700000     3478.710002  33641007.0          79.884529
# Angola       2006   11.550000     2599.565948  20149905.0          14.980000
# Argentina    2006    8.047152     5919.012338  39289876.0          91.813530
# Armenia      2006   13.200000     2158.148074   2958301.0          94.941330
#
#              Corruption  Regime types     Label
# Country
# Afghanistan   -1.446292             1     Alert
# Algeria       -0.564963             1   Warning
# Angola        -1.241038             0   Warning
# Argentina     -0.331239             2    Stable
# Armenia       -0.669233             1   Warning

# %%
groupby=df.reset_index().groupby(['Country','Label']).count()[['Year']]

# %%
groupby.to_excel(r'C:\Users\javad\Desktop\research\Data\New data\Train data\groupby.xlsx')

# %%
import matplotlib.pyplot as plt

# Pie chart, where the slices will be ordered and plotted counter-clockwise:
labels = 'Alert', 'Warning', 'Stable', 'Sustainable'
sizes = [388, 933, 316, 309]
explode = (0, 0.1, 0, 0)  # only "explode" the 2nd slice (i.e. 'Hogs')

fig1, ax1 = plt.subplots()
ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=90)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

ax1.legend(sizes, labels,
          title ="Class Distribution",
          loc ="top",
          bbox_to_anchor =(0.3,0,1,1))
 
# plt.setp( labels,size = 8, weight ="bold")
# ax1.set_title("Customizing pie chart")
# plt.legend(fig1, labels, loc="best")
# plt.axis('equal')
# plt.figure(figsize=(6,6))
plt.savefig('jj')
plt.show()

# %%
N = 3
ind = np.arange(N) 
width = 0.25
  
xvals = [0.8256,0.8830,0.9303]
bar1 = plt.bar(ind, xvals, width, color = 'g')
  
yvals = [0.9179,0.9253, 0.9445]
bar2 = plt.bar(ind+width, yvals, width, color='y')
  
zvals = [0.9256,0.963, 0.9577]
bar3 = plt.bar(ind+width*2, zvals, width, color = 'b')
plt.ylim(0.6,1)  
plt.xlabel("ML Model")
plt.ylabel('Accuracy')

  
plt.xticks(ind+width,['KNN', 'XGBOOst', 'RF'])
plt.legend( (bar1, bar2, bar3), ('Actual', 'Undersampling', 'Oversampling') ,loc='upper right', bbox_to_anchor=(1.40, 1))

plt.savefig('accuracy')

# %% [markdown]
# ## New analysis-Nov 25th
