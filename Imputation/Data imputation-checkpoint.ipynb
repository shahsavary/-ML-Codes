# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings("ignore")
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score,f1_score,precision_score
import os
import glob
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.impute import KNNImputer

# %%
df_train=pd.read_excel(r'C:\Users\javad\OneDrive - University of Windsor\Shirin Research\research\Data\New data\Train data\train data.xlsx',index_col=0)

# %%
df_test=pd.read_excel(r'C:\Users\javad\OneDrive - University of Windsor\Shirin Research\research\Data\New data\Test data\test data.xlsx',index_col=0)

# %%
df_train
# Out:
#              Year  GDP growth  Employment  GDP per capita  Population  \
# Country
# Afghanistan  2006    5.357403   41.779999      263.733602    26433058
# Algeria      2006    1.700000   37.050999     3478.710002    33641007
# Angola       2006   11.550000   55.570999     2599.565948    20149905
# Argentina    2006    8.047152   48.006001     5919.012338    39289876
# Armenia      2006   13.200000   61.664001     2158.148074     2958301
# ...           ...         ...         ...             ...         ...
# Venezuela    2018         NaN   32.040001             NaN    28887117
# Vietnam      2018    7.200000   32.158001     3230.927713    95545959
# Yemen        2018    0.752448   66.608459      758.145949    28498683
# Zambia       2018    4.034494   56.726171     1516.368371    17351714
# Zimbabwe     2018    4.824211   41.756633     1254.642265    14438812
#
#              Individuals using the Internet   School enrolment   \
# Country
# ...

# %%
df_test
# Out:
#              Year  GDP growth  Employment  GDP per capita  Population  \
# Country
# Afghanistan  2010   14.362441   41.414001      543.306526    29185511
# Algeria      2010    3.600000   37.556000     4480.786318    35977451
# Angola       2010    4.860000   55.549000     3497.974488    23356247
# Argentina    2010   10.125398   45.581001    10385.964432    40788453
# Armenia      2010    2.200000   61.983002     3218.378299     2877314
# ...           ...         ...         ...             ...         ...
# Venezuela    2019         NaN   33.051998             NaN    28515829
# Vietnam      2019    7.150000   32.283001     3425.089253    96462108
# Yemen        2019    1.400000   66.464624      750.554583    29161922
# Zambia       2019    1.441306   56.669362     1305.001031    17861034
# Zimbabwe     2019   -6.144236   41.992342     1316.740657    14645473
#
#              Individuals using the Internet   School enrolment   \
# Country
# ...

# %%
df_test.isnull().sum()
# Out:
# Year                                 0
# GDP growth                           3
# Employment                          51
# GDP per capita                       3
# Population                           0
# Individuals using the Internet      16
# School enrolment                   126
# Life expectancy at birth             0
# Democrocy Score                      0
# Voice and Accountability             0
# Control of Corruption                0
# Regime types                         0
# Label                                0
# dtype: int64

# %%
df_train.isnull().sum()
# Out:
# Year                                 0
# GDP growth                           3
# Employment                         187
# GDP per capita                       3
# Population                           0
# Individuals using the Internet      27
# School enrolment                   402
# Life expectancy at birth             0
# Democrocy Score                      0
# Voice and Accountability             0
# Control of Corruption                0
# Regime types                         0
# Label                                0
# dtype: int64

# %%
df_test['Label'].unique()
# Out:
# array(['Alert', ' Warning', 'Stable', 'Sustainable'], dtype=object)

# %%
df_train['Label'].value_counts()
# Out:
#  Warning       738
# Alert          304
# Stable         248
# Sustainable    239
# Name: Label, dtype: int64

# %%
df=pd.concat([df_test,df_train])

# %%
df.isnull().sum()
# Out:
# Year                                 0
# GDP growth                           6
# Employment                         238
# GDP per capita                       6
# Population                           0
# Individuals using the Internet      43
# School enrolment                   528
# Life expectancy at birth             0
# Democrocy Score                      0
# Voice and Accountability             0
# Control of Corruption                0
# Regime types                         0
# Label                                0
# dtype: int64

# %%
plt.figure(figsize=(12,8))
sns.heatmap(df.isna().transpose(),
            cmap="YlGnBu",
            cbar_kws={'label': 'Missing Data'})
plt.savefig("visualizing_missing_data_with_heatmap_Seaborn_Python.png", dpi=100)

# %%
sns.heatmap(df.isnull(), cbar=False)

# %%
df1=df.drop(['Label','Year'],axis=1)
df1
# Out:
#              GDP growth  Employment  GDP per capita  Population  \
# Country
# Afghanistan   14.362441   41.414001      543.306526    29185511
# Algeria        3.600000   37.556000     4480.786318    35977451
# Angola         4.860000   55.549000     3497.974488    23356247
# Argentina     10.125398   45.581001    10385.964432    40788453
# Armenia        2.200000   61.983002     3218.378299     2877314
# ...                 ...         ...             ...         ...
# Venezuela           NaN   32.040001             NaN    28887117
# Vietnam        7.200000   32.158001     3230.927713    95545959
# Yemen          0.752448   66.608459      758.145949    28498683
# Zambia         4.034494   56.726171     1516.368371    17351714
# Zimbabwe       4.824211   41.756633     1254.642265    14438812
#
#              Individuals using the Internet   School enrolment   \
# Country
# Afghanistan                         4.000000          50.567249
# ...

# %%
scaler = StandardScaler()
df1 = pd.DataFrame(scaler.fit_transform(df1), columns = df1.columns, index=df1.index)
df1.head()
# Out:
#              GDP growth  Employment  GDP per capita  Population  \
# Country
# Afghanistan    2.140113   -1.129843       -0.683959   -0.128166
# Algeria       -0.029779   -1.426346       -0.463403   -0.085865
# Angola         0.224259   -0.043510       -0.518455   -0.164472
# Argentina      1.285853   -0.809592       -0.132627   -0.055901
# Armenia       -0.312042    0.450969       -0.534116   -0.292018
#
#              Individuals using the Internet   School enrolment   \
# Country
# Afghanistan                        -1.175535          -1.082327
# Algeria                            -0.888857           0.449791
# Angola                             -1.216007          -1.885491
# Argentina                           0.207263           0.534507
# Armenia                            -0.467273           0.706720
#
#              Life expectancy at birth  Democrocy Score  \
# Country
# Afghanistan                 -1.100870        -0.646485
# ...

# %%
imputer = KNNImputer(n_neighbors=1)
df1 = pd.DataFrame(imputer.fit_transform(df1),columns = df1.columns, index=df1.index)
df1
# Out:
#              GDP growth  Employment  GDP per capita  Population  \
# Country
# Afghanistan    2.140113   -1.129843       -0.683959   -0.128166
# Algeria       -0.029779   -1.426346       -0.463403   -0.085865
# Angola         0.224259   -0.043510       -0.518455   -0.164472
# Argentina      1.285853   -0.809592       -0.132627   -0.055901
# Armenia       -0.312042    0.450969       -0.534116   -0.292018
# ...                 ...         ...             ...         ...
# Venezuela     -1.540775   -1.850273        0.184958   -0.130025
# Vietnam        0.696043   -1.841204       -0.533413    0.285139
# Yemen         -0.603894    0.806455       -0.671925   -0.132444
# Zambia         0.057823    0.046960       -0.629453   -0.201869
# Zimbabwe       0.217043   -1.103510       -0.644114   -0.220011
#
#              Individuals using the Internet   School enrolment   \
# Country
# Afghanistan                        -1.175535          -1.082327
# ...

# %%
df_imputed =pd.DataFrame(scaler.inverse_transform(df1), columns = df1.columns,index=df1.index )

# %%
df_imputed_2=df_imputed.copy()
df_imputed_2=df_imputed_2.reset_index()

# %%
df['Label'].reset_index()['Label']
# Out:
# 0          Alert
# 1        Warning
# 2        Warning
# 3         Stable
# 4        Warning
#           ...
# 1941     Warning
# 1942     Warning
# 1943       Alert
# 1944     Warning
# 1945       Alert
# Name: Label, Length: 1946, dtype: object

# %%
df_imputed_2['Label']=df['Label'].reset_index()['Label']
df_imputed_2['Year']=df['Year'].reset_index()['Year']
df_imputed_2
# Out:
#           Country  GDP growth  Employment  GDP per capita  Population  \
# 0     Afghanistan   14.362441   41.414001      543.306526  29185511.0
# 1         Algeria    3.600000   37.556000     4480.786318  35977451.0
# 2          Angola    4.860000   55.549000     3497.974488  23356247.0
# 3       Argentina   10.125398   45.581001    10385.964432  40788453.0
# 4         Armenia    2.200000   61.983002     3218.378299   2877314.0
# ...           ...         ...         ...             ...         ...
# 1941    Venezuela   -3.894386   32.040001    16055.645317  28887117.0
# 1942      Vietnam    7.200000   32.158001     3230.927713  95545959.0
# 1943        Yemen    0.752448   66.608459      758.145949  28498683.0
# 1944       Zambia    4.034494   56.726171     1516.368371  17351714.0
# 1945     Zimbabwe    4.824211   41.756633     1254.642265  14438812.0
#
#       Individuals using the Internet   School enrolment   \
# 0                            4.000000          50.567249
# ...

# %%
df_imputed_2.to_excel(r'C:\Users\javad\Desktop\research\Data\New data\Imputed data\imputed.xlsx')

# %%
df_imputed
# Out:
#       GDP growth  GDP per capita  Population      School  \
# 0      14.362441      543.306526  29185511.0   50.567249
# 1       3.600000     4480.786318  35977451.0   96.937279
# 2       4.860000     3497.974488  23356247.0   26.259220
# 3      10.125398    10385.964432  40788453.0   99.501259
# 4       2.200000     3218.378299   2877314.0  104.713318
# ...          ...             ...         ...         ...
# 1941         NaN             NaN  28887117.0         NaN
# 1942    7.200000     3230.927713  95545959.0  110.594810
# 1943    0.752448      758.145949  28498683.0         NaN
# 1944    4.034494     1516.368371  17351714.0         NaN
# 1945    4.824211     1254.642265  14438812.0   97.750809
#
#       Life expectancy at birth  Democrocy Score  Regime types     Label
# 0                       61.028            0.377           1.0     Alert
# 1                       74.938            0.328           1.0   Warning
# ...

# %%
# Out:
#   File "<ipython-input-37-dda7b70f1085>", line 10
#     ax.legend(p1[0],p2[0],p3[0]),('A','B','C'))
#                                               ^
# SyntaxError: invalid syntax
